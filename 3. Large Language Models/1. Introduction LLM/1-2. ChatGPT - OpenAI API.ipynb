# %% [markdown]
# # [OpenAI API란?](https://velog.io/@euisuk-chung/%EC%A0%95%EB%A6%AC-OpenAI-API-Document#5-%ED%8C%8C%EC%9D%B8%ED%8A%9C%EB%8B%9D%EB%90%9C-%EB%AA%A8%EB%8D%B8-%EC%82%AC%EC%9A%A9-%EB%B0%A9%EB%B2%95)
# - OpenAI는 최신 인공지능(AI) 모델과 API를 제공하여 개발자들이 다양한 AI 기능을 쉽게 애플리케이션에 통합할 수 있도록 지원합니다.
# - OpenAI를 활용하면, 자연어 처리, 이미지 생성, 음성 인식 등 다양한 AI 작업을 간단하게 구현할 수 있으며, 사용자 경험을 혁신적으로 개선할 수 있습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## [1.OpenAI 접속 및 회원가입](https://platform.openai.com/docs/overview)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.결제정보 등록

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## [3.OpenAI API Key 발급받기](https://platform.openai.com/api-keys)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## [4.OpenAI 요금](https://openai.com/api/pricing/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## [5.OpenAI 모델](https://platform.openai.com/docs/models)

# %% [markdown]
# ### GPT-4o
# - GPT-4o("o"는 "omni"를 의미)는 가장 진보된 GPT 모델입니다.
# - 멀티모달(텍스트나 이미지 입력을 받고 텍스트를 출력)이며 GPT-4 Turbo와 동일한 높은 지능을 가지고 있지만 훨씬 더 효율적입니다.
# - 텍스트를 2배 더 빠르게 생성하고 50% 더 저렴합니다.
# - 또한 GPT-4o는 모든 모델 중에서 영어가 아닌 언어에 대한 최고의 비전과 성능을 제공합니다.
# - GPT-4o는 유료 고객에게 OpenAI API에서 제공됩니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### GPT-4o mini
# - GPT-4o mini("omni"의 "o")는 소형 모델 카테고리에서 가장 진보된 모델이자 가장 저렴한 모델입니다.
# - 멀티모달(텍스트 또는 이미지 입력을 허용하고 텍스트 출력)이며 gpt-3.5-turbo보다 ​​지능이 높지만 속도는 동일합니다. 비전 작업을 포함한 소규모 작업에 사용됩니다.
# - 이전에 gpt-3.5-turbo를 사용했던 곳에서 gpt-4o-mini를 선택하는 것이 좋습니다. 이 모델이 더 성능이 좋고 저렴하기 때문입니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### GPT-3.5 Turbo
# - GPT-3.5 Turbo 모델은 자연어 또는 코드를 이해하고 생성할 수 있으며 Chat Completions API를 사용하여 채팅에 최적화되었지만 채팅이 아닌 작업에도 잘 작동합니다.
# - 2024년 7월부터 gpt-3.5-turbo 대신 gpt-4o-mini를 사용해야 합니다. gpt-4o-mini는 더 저렴하고 성능이 뛰어나며 다중 모드이며 빠르기 때문입니다.
# - API에서는 gpt-3.5-turbo를 계속 사용할 수 있습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Embeddings
# - 임베딩은 두 텍스트 사이의 관련성을 측정하는 데 사용할 수 있는 텍스트의 숫자 표현입니다.
# - 임베딩은 검색, 클러스터링, 추천, 변칙 검색 및 분류 작업에 유용합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### DALL·E
# - DALL·E는 자연어 설명을 통해 사실적인 이미지와 예술 작품을 만들어내는 AI 시스템이다.
# - DALL·E 3은 현재 프롬프트가 표시되면 특정 크기의 새 이미지를 생성하는 기능을 지원합니다.
# - DALL·E 2는 기존 이미지를 편집하거나 사용자가 제공한 이미지의 변형을 생성하는 기능도 지원합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Setup

# %% [markdown]
# ## install

# %%
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## OpenAI Key 등록

# %%
import os

os.environ['OPENAI_API_KEY'] = '생성한 키 입력'

# %% [markdown]
# # OpenAI 주요 기능들
# - OpenAI API는 다양한 기능을 제공하며, 이를 통해 텍스트 생성, 이미지 처리, 음성 인식 등 다양한 작업을 수행할 수 있습니다.

# %%
from openai import OpenAI

client = OpenAI()

# %% [markdown]
# ## [텍스트 생성 (Text Generation)](https://platform.openai.com/docs/guides/text-generation)
# - 텍스트 생성은 OpenAI API의 가장 기본적이면서도 강력한 기능 중 하나입니다.
# - GPT-4와 같은 언어 모델을 사용하여 사용자 프롬프트에 기반한 다양한 텍스트를 생성할 수 있습니다.

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini", #"gpt-4",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {
            "role": "user",
            "content": "용과 싸우는 용감한 기사에 대한 이야기를 써 보세요."
        }
    ]
)

# %%
print(completion.choices[0].message.content)
# Out:
# 옛날 옛적, 드넓은 왕국에는 용이 나타나 사람들을 괴롭히고, 마을을 불태우며 두려움을 주고 있었다. 그 용의 이름은 '화르곤'으로, 불길한 힘을 가진 강력한 존재였다. 많은 기사들이 용과 싸우기 위해 나섰지만, 화르곤의 위력에 모두 패하고 말았다.
#
# 이런 상황 속에서 한 젊은 기사가 나타났다. 그의 이름은 에드윈으로, 왕국의 작은 마을 출신이었다. 에드윈은 어렸을 적부터 전설적인 기사들이 용과 싸운 이야기를 들으며 자랐고, 자신도 그 전설의 주인공이 되기를 간절히 원했다. 이제 그 기회가 왔고, 그는 용감한 결심을 하고 화르곤에 맞서기로 했다.
#
# 에드윈은 평범한 아들이었지만, 그의 마음속에는 불굴의 의지가 타오르고 있었다. 그는 훈련을 위해 며칠 밤을 새워가며 검술을 연마하고, 방어 기술을 익혔다. 그리고 왕국의 마법사에게 찾아가 특별한 마법의 방패를 만들어 달라고 요청했다. 마법사는 그의 용기와 결의에 감동하여 새로운 방패를 만들어주었다. 그 방패는 용의 불길을 막아주는 힘을 지니고 있었다.
#
# 마침내 에드윈은 용과의 결전의 날이 다가왔다. 마을 사람들은 그를 걱정스러운 눈으로 바라봤지만, 에드윈은 두려움을 이겨내고 화르곤이 나타날 장소로 나아갔다. 거대한 암석과 불길한 기운이 맴도는 그곳은 마치 저주받은 땅처럼 느껴졌다.
#
# 드디어 화르곤이 하늘을 가르며 나타났다. 그의 비늘은 햇빛을 받아 반짝였고, 그 눈에서 불꽃이 튀어 나왔다. 에드윈은 침착하게 검을 뽑아들고, 마법의 방패를 앞으로 향했다.
#
# “용이여, 너의 폭력을 그만두어라!” 에드윈은 용감하게 외쳤다.
#
# 그러자 화르곤은 소름 돋는 웃음을 지으며 대답했다. “작은 인간아, 너는 나를 이길 수 없다!”
#
# 전투가 시작되었다. 화르곤은 에드윈을 향해 불길을 뿜어내었고, 에드윈은 마법의 방패로 그것을 막았다. 방패는 위력을 쏟아내는 불길에 휘둘리지 않고 그를 보호했다. 에드윈은 반격의 기회를 노리며 검을 높이 휘둘렀다.
#
# ...

# %% [markdown]
# ## [이미지 생성 (Vision)](https://platform.openai.com/docs/guides/images)
# - OpenAI의 DALL·E 모델은 텍스트 설명을 기반으로 이미지를 생성하는 데 사용됩니다.
# - 이 기능을 사용하여 창의적이고 독창적인 이미지를 만들 수 있습니다.

# %%
response = client.images.generate(
  model="dall-e-3",
  prompt="a white siamese cat",
  size="1024x1024",
  quality="standard",
  n=1,
)

# %%
image_url = response.data[0].url
print("Generated image URL:", image_url)
# Out:
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-skfyM5AiLazN2flLZLetQmiT/user-6CDDmIuQhLxzi15TnEaLAUDg/img-IgBdX8uLTpRRo03YX09unxdt.png?st=2024-10-16T09%3A37%3A02Z&se=2024-10-16T11%3A37%3A02Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-15T18%3A09%3A06Z&ske=2024-10-16T18%3A09%3A06Z&sks=b&skv=2024-08-04&sig=BQGk5ObWhfbmB0L57uukn8aoQZe5ndM08%2Bzd2OoV/Bo%3D

# %% [markdown]
# ## [이미지 해석](https://platform.openai.com/docs/guides/vision)

# %%
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-skfyM5AiLazN2flLZLetQmiT/user-6CDDmIuQhLxzi15TnEaLAUDg/img-IgBdX8uLTpRRo03YX09unxdt.png?st=2024-10-16T09%3A37%3A02Z&se=2024-10-16T11%3A37%3A02Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-15T18%3A09%3A06Z&ske=2024-10-16T18%3A09%3A06Z&sks=b&skv=2024-08-04&sig=BQGk5ObWhfbmB0L57uukn8aoQZe5ndM08%2Bzd2OoV/Bo%3D'

# %%
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "What’s in this image?"},
        {
          "type": "image_url",
          "image_url": {
            "url": image_url,
          },
        },
      ],
    }
  ],
  max_tokens=300,
)

# %%
print(response.choices[0].message.content)
# Out:
# The image depicts an illustration of a Siamese cat. The cat has a cream-colored body with darker points on its ears, face, paws, and tail. It features large, expressive blue eyes and a sleek, stylized appearance. The background is a light beige color, emphasizing the cat's distinct markings.

# %% [markdown]
# ## [구조화된 출력 (Structured Outputs)](https://platform.openai.com/docs/guides/structured-outputs)
# - OpenAI 모델은 JSON과 같은 구조화된 데이터를 출력할 수 있습니다.
# - 이를 통해 특정 형식으로 데이터를 받을 수 있어, 프로그램에서 데이터를 더 쉽게 처리할 수 있습니다.

# %%
from pydantic import BaseModel

class CalendarEvent(BaseModel):
    name: str
    date: str
    participants: list[str]

# %%
completion = client.beta.chat.completions.parse(
    model="gpt-4o-mini", #"gpt-4o-2024-08-06",
    messages=[
        {"role": "system", "content": "Extract the event information."},
        {"role": "user", "content": "Alice and Bob are going to a science fair on Friday."},
    ],
    response_format=CalendarEvent,
)

# %%
completion.choices[0].message
# Out:
# ParsedChatCompletionMessage[CalendarEvent](content='{"name":"Science Fair","date":"Friday","participants":["Alice","Bob"]}', refusal=None, role='assistant', function_call=None, tool_calls=[], parsed=CalendarEvent(name='Science Fair', date='Friday', participants=['Alice', 'Bob']))

# %%
event = completion.choices[0].message.parsed
event
# Out:
# CalendarEvent(name='Science Fair', date='Friday', participants=['Alice', 'Bob'])

# %% [markdown]
# ## [복잡한 추론 (Reasoning)](https://platform.openai.com/docs/guides/reasoning)
# - OpenAI 모델은 복잡한 문제에 대해 논리적으로 추론할 수 있습니다.
# - 수학 문제 해결, 코드 디버깅 등 다양한 추론 작업을 수행할 수 있습니다.

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini", #"o1-preview",
    messages=[
        {
            "role": "user",
            "content": "Solve the equation: 5x - 3 = 12"
        }
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# To solve the equation \( 5x - 3 = 12 \), follow these steps:
#
# 1. Add 3 to both sides of the equation to isolate the term with \( x \):
#
#    \[
#    5x - 3 + 3 = 12 + 3
#    \]
#    \[
#    5x = 15
#    \]
#
# 2. Next, divide both sides by 5 to solve for \( x \):
#
#    \[
#    x = \frac{15}{5}
#    \]
#    \[
#    x = 3
#    \]
#
# So, the solution is \( x = 3 \).

# %% [markdown]
# # OpenAI 응용

# %% [markdown]
# ## Client 생성
# - client는 OpenAI 모듈로 생성된 인스턴스 입니다.

# %%
from openai import OpenAI

# client는 OpenAI 모듈로 생성된 인스턴스 입니다.
client = OpenAI()

# %% [markdown]
# ## [Chat](https://platform.openai.com/docs/api-reference/chat)
# - 채팅 모델은 메시지 목록을 입력으로 받고 모델이 생성한 메시지를 출력으로 반환합니다.
# - 채팅 형식은 여러 차례에 걸친 대화를 쉽게 할 수 있도록 설계되었지만, 대화가 없는 단일 턴 작업에도 유용합니다.

# %% [markdown]
# ### 주요 파라미터

# %% [markdown]
# - `messages`: 지금까지의 대화를 구성하는 메시지 목록입니다.
# - `frequency_penalty`: -2.0에서 2.0 사이의 숫자. 양수 값은 지금까지 텍스트에 나타난 기존 빈도에 따라 새로운 토큰에 불이익을 주어 모델이 같은 줄을 그대로 반복할 가능성을 낮춥니다.
# - `max_tokens`: 생성할 수 있는 최대 토큰 수입니다. 입력 토큰과 생성된 토큰의 총 길이는 모델의 컨텍스트 길이에 의해 제한됩니다.
# - `n`: 각 입력 메시지에 대해 생성할 선택지(choices) 수입니다. `[주의]` 모든 선택 항목에서 생성된 토큰 수에 따라 요금이 부과된다는 점에 유의하세요. 비용을 최소화하려면 n을 1로 유지하세요.
# - `presence_penalty`: -2.0에서 2.0 사이의 숫자. 값이 양수이면 지금까지 텍스트에 등장한 토큰에 따라 새로운 토큰에 불이익을 주므로 모델이 새로운 주제에 대해 이야기할 가능성이 높아집니다.
# - `response_format`: 모델이 출력해야 하는 형식을 지정하는 객체입니다. `gpt-4-1106-preview` 및 `gpt-3.5-turbo-1106` 과 호환됩니다. `{ "type": "json_object" }` 로 설정하면 JSON 모드가 활성화되어 모델이 생성하는 메시지가 유효한 JSON임을 보장합니다.
# - `seed`: 이 기능을 지정하면 시스템이 결정론적으로 샘플링하여 동일한 시드와 매개변수를 사용한 반복 요청이 동일한 결과를 반환하도록 최선을 다할 것입니다. 결정론은 보장되지 않으며, `system_fingerprint` 응답 매개변수를 참조하여 백엔드의 변경 사항을 모니터링해야 합니다.
# - `temperature`: 0에서 2 사이에서 사용할 샘플링 온도입니다. 0.8과 같이 값이 높으면 출력이 더 무작위적이고, 0.2와 같이 값이 낮으면 더 집중적이고 결정론적인 출력이 됩니다. 일반적으로 이 값이나 `top_p` 중 하나만 변경하는 것이 좋지만 둘 다 변경하지는 않는 것이 좋습니다.
# - `top_p`: `temperature` 를 이용한 샘플링의 대안으로, 핵 샘플링이라고 하며, 모델이 `top_p` 확률을 가진 토큰의 결과를 고려하는 방식입니다. 따라서 0.1은 상위 10% 확률을 구성하는 토큰만 고려한다는 의미입니다. 일반적으로 이 값이나 `temperature` 중 하나를 변경하는 것이 좋지만 둘 다 변경하는 것은 권장하지 않습니다.

# %% [markdown]
# - Client 생성하기
#   - client 는 OpenAI 모듈로 생성된 인스턴스 입니다.

# %% [markdown]
# ### [ChatGPT 모델 정의](https://platform.openai.com/docs/models)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model = "gpt-4o-mini"

# %% [markdown]
# ### messages

# %% [markdown]
# - 메시지 설정하기
#   - `시스템 메시지` : ‘You are a helpful assistant.’와 같은 메시지로 챗봇에게 일종의 역할을 부여
#   - `사용자 메시지` : 도우미에게 직접 전달하는 내용

# %%
messages = [{
    "role": "system",
    "content": "당신은 파이썬 프로그래머입니다."
}, {
    "role": "user",
    "content": "피보나치 수열을 생성하는 파이썬 프로그램을 작성해주세요."
}]

# %% [markdown]
# ### [ChatCompletions](https://platform.openai.com/docs/api-reference/chat)
#   - 채팅 모델은 메시지 목록을 입력으로 받고 모델이 생성한 메시지를 출력으로 반환합니다.

# %%
completion = client.chat.completions.create(
    model=model,
    messages=messages
)

# %%
completion.choices
# Out:
# [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='피보나치 수열을 생성하는 파이썬 프로그램을 아래와 같이 작성할 수 있습니다. 이 예제는 사용자가 원하는 항의 개수를 입력받아 해당 개수만큼의 피보나치 수열을 출력합니다.\n\n```python\ndef fibonacci_sequence(n):\n    fib_sequence = []\n    a, b = 0, 1\n    for _ in range(n):\n        fib_sequence.append(a)\n        a, b = b, a + b\n    return fib_sequence\n\n# 사용자로부터 입력 받기\nnum_terms = int(input("원하는 피보나치 수열의 항의 개수를 입력하세요: "))\nsequence = fibonacci_sequence(num_terms)\n\nprint("피보나치 수열:", sequence)\n```\n\n이 프로그램은 피보나치 수열의 첫 `n` 항을 리스트로 생성하여 출력합니다. 사용자가 항의 개수를 입력하면, 해당 수만큼의 피보나치 수를 생성합니다.', refusal=None, role='assistant', function_call=None, tool_calls=None))]

# %%
completion.choices[0].message
# Out:
# ChatCompletionMessage(content='피보나치 수열을 생성하는 파이썬 프로그램을 아래와 같이 작성할 수 있습니다. 이 예제는 사용자가 원하는 항의 개수를 입력받아 해당 개수만큼의 피보나치 수열을 출력합니다.\n\n```python\ndef fibonacci_sequence(n):\n    fib_sequence = []\n    a, b = 0, 1\n    for _ in range(n):\n        fib_sequence.append(a)\n        a, b = b, a + b\n    return fib_sequence\n\n# 사용자로부터 입력 받기\nnum_terms = int(input("원하는 피보나치 수열의 항의 개수를 입력하세요: "))\nsequence = fibonacci_sequence(num_terms)\n\nprint("피보나치 수열:", sequence)\n```\n\n이 프로그램은 피보나치 수열의 첫 `n` 항을 리스트로 생성하여 출력합니다. 사용자가 항의 개수를 입력하면, 해당 수만큼의 피보나치 수를 생성합니다.', refusal=None, role='assistant', function_call=None, tool_calls=None)

# %%
completion.choices[0].message.content
# Out:
# '피보나치 수열을 생성하는 파이썬 프로그램을 아래와 같이 작성할 수 있습니다. 이 예제는 사용자가 원하는 항의 개수를 입력받아 해당 개수만큼의 피보나치 수열을 출력합니다.\n\n```python\ndef fibonacci_sequence(n):\n    fib_sequence = []\n    a, b = 0, 1\n    for _ in range(n):\n        fib_sequence.append(a)\n        a, b = b, a + b\n    return fib_sequence\n\n# 사용자로부터 입력 받기\nnum_terms = int(input("원하는 피보나치 수열의 항의 개수를 입력하세요: "))\nsequence = fibonacci_sequence(num_terms)\n\nprint("피보나치 수열:", sequence)\n```\n\n이 프로그램은 피보나치 수열의 첫 `n` 항을 리스트로 생성하여 출력합니다. 사용자가 항의 개수를 입력하면, 해당 수만큼의 피보나치 수를 생성합니다.'

# %%
print(completion.choices[0].message.content)
# Out:
# 피보나치 수열을 생성하는 파이썬 프로그램을 아래와 같이 작성할 수 있습니다. 이 예제는 사용자가 원하는 항의 개수를 입력받아 해당 개수만큼의 피보나치 수열을 출력합니다.
#
# ```python
# def fibonacci_sequence(n):
#     fib_sequence = []
#     a, b = 0, 1
#     for _ in range(n):
#         fib_sequence.append(a)
#         a, b = b, a + b
#     return fib_sequence
#
# # 사용자로부터 입력 받기
# num_terms = int(input("원하는 피보나치 수열의 항의 개수를 입력하세요: "))
# sequence = fibonacci_sequence(num_terms)
#
# print("피보나치 수열:", sequence)
# ```
#
# 이 프로그램은 피보나치 수열의 첫 `n` 항을 리스트로 생성하여 출력합니다. 사용자가 항의 개수를 입력하면, 해당 수만큼의 피보나치 수를 생성합니다.

# %% [markdown]
# ## 스트리밍(Streaming)
# - 스트리밍은 실시간으로 데이터를 전송하고 수신하는 프로세스입니다.
# - 이 기능을 사용하면, 대화형 모델이 토큰 단위로 응답을 생성하고, 사용자는 모델이 응답을 생성하는 과정을 실시간으로 볼 수 있습니다.
# - 이는 특히 긴 답변을 생성하는 경우 유용하며, 사용자에게 대화가 더 자연스럽고 동적으로 느껴지게 만듭니다.

# %% [markdown]
# ### completion
# - Jupyter Notebook에서 스트리밍 형식으로 실시간 답변을 출력하려면, 아래와 같이 `tream=True` 지정하면 됩니다.
# - 또한, 토큰 단위로 실시간 출력을 위해서는 completion 을 순회하면서, `choices.delta.content` 를 출력해야 합니다.

# %%
completion = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {
            "role": "system",
            "content": "당신은 파이썬 프로그래머입니다.",
        },
        {
            "role": "user",
            "content": "피보나치 수열을 생성하는 파이썬 프로그램을 작성해주세요.",
        },
    ],
    stream=True,  # 스트림 모드 활성화
)

# %%
final_answer = []

# 스트림 모드에서는 completion.choices 를 반복문으로 순회
for chunk in completion:
    # chunk 를 저장
    chunk_content = chunk.choices[0].delta.content
    # chunk 가 문자열이면 final_answer 에 추가
    if isinstance(chunk_content, str):
        final_answer.append(chunk_content)
        # 토큰 단위로 실시간 답변 출력
        print(chunk_content, end="")
# Out:
# 피보나치 수열은 첫 번째 항이 0이고 두 번째 항이 1이며, 세 번째 항부터는 바로 앞 두 항의 합으로 이루어지는 수열입니다. 아래는 피보나치 수열을 생성하는 파이썬 프로그램입니다.
#
# ```python
# def fibonacci(n):
#     fib_list = [0, 1]
#     if n <= 0:
#         return "유효한 입력 값이 아닙니다."
#     elif n == 1:
#         return [0]
#     elif n == 2:
#         return fib_list
#     else:
#         for i in range(2, n):
#             fib_list.append(fib_list[i-1] + fib_list[i-2])
#         return fib_list
#
# n = int(input("피보나치 수열의 길이를 입력하세요: "))
# result = fibonacci(n)
# print(result)
# ```
#
# 이 프로그램은 사용자로부터 피보나치 수열의 길이를 입력받고, 해당 길이만큼의 피보나치 수열을 생성하여 출력합니다.

# %%
# 전체 답변인 final_answer 를 문자열로 변환하여 출력
final_answer = "".join(final_answer)
print(final_answer)
# Out:
# 피보나치 수열은 첫 번째 항이 0이고 두 번째 항이 1이며, 세 번째 항부터는 바로 앞 두 항의 합으로 이루어지는 수열입니다. 아래는 피보나치 수열을 생성하는 파이썬 프로그램입니다.
#
# ```python
# def fibonacci(n):
#     fib_list = [0, 1]
#     if n <= 0:
#         return "유효한 입력 값이 아닙니다."
#     elif n == 1:
#         return [0]
#     elif n == 2:
#         return fib_list
#     else:
#         for i in range(2, n):
#             fib_list.append(fib_list[i-1] + fib_list[i-2])
#         return fib_list
#
# n = int(input("피보나치 수열의 길이를 입력하세요: "))
# result = fibonacci(n)
# print(result)
# ```
#
# 이 프로그램은 사용자로부터 피보나치 수열의 길이를 입력받고, 해당 길이만큼의 피보나치 수열을 생성하여 출력합니다.

# %% [markdown]
# ## 이전 대화내용 기억(대화의 연속성)
# - `client.chat.completions.create()` 함수는 자체적으로 대화를 저장하는 기능이 없습니다.
# - 따라서, 이전 문맥(context)을 기억하면서 대화를 이어나가기 위해서는(일반적인 ChatBot을 생각하시면 됩니다) 다음과 같이 `messages` 옵션에 메시지를 추가해야 합니다.

# %% [markdown]
# 각 “role”의 의미는 다음과 같습니다:
#
# - `system`: 시스템 전역 설정에 대한 지시문을 포함합니다. 예를 들어, 모델에 특정한 페르소나(persona)를 부여하거나, 대화의 맥락을 설정하는 데 사용됩니다.
# - `user`: 사용자의 입력을 나타냅니다. 이는 대화에서 사용자가 질문하거나 요청한 내용을 담고 있습니다.
# - `assistant`: AI 모델(예: ChatGPT)의 응답을 나타냅니다. 이는 모델이 생성한 답변이나 정보를 포함합니다.

# %% [markdown]
# ### 이전 대화를 기억하지 못하는 예제

# %%
def ask(question):
    completion = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {
                "role": "system",
                "content": "You are a helpful assistant. You must answer in Korean.",
            },
            {
                "role": "user",
                "content": question,  # 사용자의 질문을 입력
            },
        ],
    )
    # 답변을 반환
    return completion.choices[0].message.content

# %%
# 첫 번째 질문
ask("대한민국의 수도는 어디인가요?")
# Out:
# '대한민국의 수도는 서울입니다.'

# %% [markdown]
# - 답변에서 보듯이, GPT가 다음 질문에 대한 답변을 잘못했습니다. 이는 이전 대화내용에 대한 저장을 하지 않았기 때문입니다.

# %%
# 두 번째 질문
ask("영어로 답변해 주세요")
# Out:
# '저는 한국어로 대화할 수밖에 없습니다. 도와드릴 일이 있으면 언제든지 말씀해 주세요.'

# %% [markdown]
# ### 이전 대화를 기억하는 예제

# %%
def ask(question, message_history=[], model="gpt-3.5-turbo"):
    if len(message_history) == 0:
        # 최초 질문
        message_history.append(
            {
                "role": "system",
                "content": "You are a helpful assistant. You must answer in Korean.",
            }
        )

    # 사용자 질문 추가
    message_history.append(
        {
            "role": "user",
            "content": question,
        },
    )

    # GPT에 질문을 전달하여 답변을 생성
    completion = client.chat.completions.create(
        model=model,
        messages=message_history,
    )

    # 사용자 질문에 대한 답변을 추가
    message_history.append(
        {"role": "assistant", "content": completion.choices[0].message.content}
    )

    return message_history

# %%
# 최초 질문
message_history = ask("대한민국의 수도는 어디인가요?", message_history=[])
# 최초 답변
print(message_history[-1])
# Out:
# {'role': 'assistant', 'content': '대한민국의 수도는 서울입니다.'}

# %%
# 두 번째 질문
message_history = ask("이전의 내용을 영어로 답변해 주세요", message_history=message_history)
# 두 번째 답변
print(message_history[-1])
# Out:
# {'role': 'assistant', 'content': 'The capital of South Korea is Seoul.'}

# %% [markdown]
# ## json_object 답변형식
# - 이번에는 GPT 의 출력 형식을 지정하는 방법을 살펴보겠습니다.
# - 다음의 예시는 프롬프트를 활용하여 답변을 JSON 형식으로 받는 예제 입니다.

# %%
completion = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    messages=[
        {
            "role": "system",
            # 답변 형식을 JSON 으로 받기 위해 프롬프트에 JSON 형식을 지정
            "content": "You are a helpful assistant designed to output JSON. You must answer in Korean.",
        },
        {
            "role": "user",
            "content": "대한민국의 수도는 어디인가요?",
        },
    ],
    response_format={"type": "json_object"},  # 답변 형식을 JSON 으로 지정
)

print(completion.choices[0].message.content)
# Out:
# {
#   "답변": "대한민국의 수도는 서울입니다."
# }

# %% [markdown]
# - `response_format={"type": "json_object"}` 으로 출력시 json 형태로 출력되는 것을 확인할 수 있습니다.

# %%
response = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    response_format={"type": "json_object"},
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant designed to output JSON.",
        },
        {"role": "user", "content": "통계를 주제로 4지선다형 객관식 문제를 만들어주세요."},
    ],
    temperature=0.5,
    max_tokens=300,
)
print(response.choices[0].message.content)
# Out:
# {
#   "question": "다음 중 통계학의 기본 용어가 아닌 것은?",
#   "options": ["평균", "중앙값", "상관관계", "표준편차"],
#   "answer": "상관관계"
# }

# %% [markdown]
# - `json` 형식으로 출력 값을 받으면 데이터베이스에 저장하거나 파일형태로 저장하는데 용이합니다.

# %%
response = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    response_format={"type": "json_object"},
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant designed to output JSON.",
        },
        {
            "role": "user",
            "content": "통계를 주제로 4지선다형 객관식 문제를 만들어주세요. 정답은 index 번호로 알려주세요. "
            "난이도는 [상, 중, 하] 중 하나로 표기해 주세요.",
        },
    ],
    temperature=0.5,
    max_tokens=300,
    n=5,
)

# %%
for res in response.choices:
    print(res.message.content)
# Out:
# {
#   "question": "다음 중 통계학에서 사용되는 중심 경향성을 나타내는 지표는 무엇인가요?",
#   "options": ["표준편차", "중앙값", "범위", "평균"],
#   "answer": 3,
#   "difficulty": "하"
# }
# {
#   "question": "다음 중 통계 용어가 아닌 것은?",
#   "options": ["평균", "분산", "직선", "표준편차"],
#   "answer": 2,
#   "difficulty": "하"
# }
# {
#   "question": "다음 중 통계학에서 사용되는 중심 경향성을 나타내는 지표는 무엇인가요?",
#   "options": ["표준편차", "평균", "분산", "중앙값"],
#   "answer": 1,
#   "difficulty": "하"
# }
# {
#   "question": "다음 중 통계학에서 사용되는 중심 경향성을 나타내는 지표는 무엇인가요?",
#   "options": ["표준편차", "평균", "분산", "중앙값"],
#   "answer": 1,
#   "difficulty": "하"
# }
# {
#   "question": "다음 중 통계학에서 사용되는 가설검정의 단계 중 가설을 설정하는 단계는 무엇인가요?",
#   "options": ["가설 검정", "가설 설정", "표본 추출", "결과 해석"],
#   "answer": 1,
#   "difficulty": "하"
# }

# %% [markdown]
# ### 파이썬 객체로 변환

# %%
import json

# JSON 형식의 답변을 파이썬 객체로 변환
json_obj = json.loads(res.message.content)
json_obj
# Out:
# {'question': '다음 중 통계학에서 사용되는 가설검정의 단계 중 가설을 설정하는 단계는 무엇인가요?',
#  'options': ['가설 검정', '가설 설정', '표본 추출', '결과 해석'],
#  'answer': 1,
#  'difficulty': '하'}

# %%
# 모든 json 형식의 답변을 파이썬 객체로 변환
json_result = [json.loads(res.message.content) for res in response.choices]
json_result
# Out:
# [{'question': '다음 중 통계학에서 사용되는 중심 경향성을 나타내는 지표는 무엇인가요?',
#   'options': ['표준편차', '중앙값', '범위', '평균'],
#   'answer': 3,
#   'difficulty': '하'},
#  {'question': '다음 중 통계 용어가 아닌 것은?',
#   'options': ['평균', '분산', '직선', '표준편차'],
#   'answer': 2,
#   'difficulty': '하'},
#  {'question': '다음 중 통계학에서 사용되는 중심 경향성을 나타내는 지표는 무엇인가요?',
#   'options': ['표준편차', '평균', '분산', '중앙값'],
#   'answer': 1,
#   'difficulty': '하'},
#  {'question': '다음 중 통계학에서 사용되는 중심 경향성을 나타내는 지표는 무엇인가요?',
#   'options': ['표준편차', '평균', '분산', '중앙값'],
#   'answer': 1,
#   'difficulty': '하'},
#  {'question': '다음 중 통계학에서 사용되는 가설검정의 단계 중 가설을 설정하는 단계는 무엇인가요?',
#   'options': ['가설 검정', '가설 설정', '표본 추출', '결과 해석'],
#   'answer': 1,
#   'difficulty': '하'}]

# %% [markdown]
# ### Pandas로 변환

# %%
import pandas as pd

# 데이터프레임으로 변환
df = pd.DataFrame(json_result)
df.head()
# Out:
#                                          question  \
# 0         다음 중 통계학에서 사용되는 중심 경향성을 나타내는 지표는 무엇인가요?
# 1                              다음 중 통계 용어가 아닌 것은?
# 2         다음 중 통계학에서 사용되는 중심 경향성을 나타내는 지표는 무엇인가요?
# 3         다음 중 통계학에서 사용되는 중심 경향성을 나타내는 지표는 무엇인가요?
# 4  다음 중 통계학에서 사용되는 가설검정의 단계 중 가설을 설정하는 단계는 무엇인가요?
#
#                         options  answer difficulty
# 0           [표준편차, 중앙값, 범위, 평균]       3          하
# 1            [평균, 분산, 직선, 표준편차]       2          하
# 2           [표준편차, 평균, 분산, 중앙값]       1          하
# 3           [표준편차, 평균, 분산, 중앙값]       1          하
# 4  [가설 검정, 가설 설정, 표본 추출, 결과 해석]       1          하
