# %% [markdown]
# # [미분은 변화량이다!!](https://www.youtube.com/watch?v=glW0ugwYvnA)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 아래 그림을 보면 기울기가 (+)이면 녹색이 되고, (-)이면 빨간색이 되며, 기울기가 (0)이되면 검정색이 된다.
# - 기울기는 y의 변화량(△y)을 x의 변화량(△x)으로 나눔으로써 구할 수 있다는 것을 알 수 있다.
# - 차분은 변화량을, 즉 두 값의 차이를 뜻한다.
#   - x에 대한 차분을 설명한다면, x2와 x1 사이의 간격을 의미하며 수식으로는 △x = x2 - x1 표현할 수 있다.

# %% [markdown]
# ![img](https://blog.kakaocdn.net/dn/llf7F/btqPgGY3Z2B/ldfAmTn8AKfbwnCWbIlax1/img.gif)

# %% [markdown]
# ## 미분을 좀더 이해해보자

# %% [markdown]
# - 예를 들어 f(x) = x^2일 경우 이를 미분하면 f'(x) =2x이다.
# - 위의 그래프에서 f(3) = 9이며, 이는 입력 x=3에서 출력은 9임을 의미한다.
# - 그리고 f'(x) = 6이며, 입력 x = 3을 미세하게 변화시킬 때 함수의 현재 값의 2배인 6변화를 일으킴을 의미한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # [편미분, 전미분](https://velog.io/@swan9405/%ED%8E%B8%EB%AF%B8%EB%B6%84%EA%B3%BC-%EC%A0%84%EB%AF%B8%EB%B6%84)
# - 다른 변수에 영향을 받지 않는 독립적인 변수를 독립 변수,
# - 다른 변수에 영향을 받는 변수를 종속 변수라고 하는데,
# - 함수값을 결정할 때 2개 이상의 독립 변수가 필요한 함수를 다변수 함수라고 한다.
# - $y=f(x_1, x_2, x_3, ..., x_n)$와 같은 형태로 쓰는데, 이러한 다변수 함수를 미분할 때 사용하는 것이 편미분과 전미분이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 편미분
# 편미분은 다변수 함수에서 관심이 있는 한 변수만 변수로 생각하고, 나머지 변수들은 상수로 취급한 뒤 미분하는 방법이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 어떤 함수를 미분한 함수를 도함수라고 하듯이, 어떤 함수를 편미분한 함수를 편도함수라고 한다.
# - 편도함수를 나타내는 방법도 일반적인 도함수를 나타내는 방법과 비슷하지만, 도함수와 구분해야 하고, 여러 변수 중 어떤 변수만 변수로 취급하고 미분했는지 표시해야 하기 때문에 f'x(x, y, z, ...), ∂f/∂x와 같은 표현을 사용한다.
# - 편미분을 할 때는 미분 연산자가 ∂f/∂x와 같이 d 대신 ∂를 사용한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 위 3차원 그래프는 $z=x^2+xy+y^2$라는 함수의 그래프인데, y=1로 고정했을 때 절단면이 바로 빨간색 곡선입니다.
# - 저 빨간색 곡선에서 접선의 기울기를 구하는 것이 바로 x에 대한 z의 편미분이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 전미분
# - 전미분은 각각의 변수에 대한 편미분을 구한 뒤 모두 더하면 된다.
# - 이때 dx, dy, dz, ...는 증분, 즉 변화량을 말한다.
# - 이렇게 함수를 전미분 한 함수를 전도함수라고 하고, 모든 변수에 대해 미분하는 것이기 때문에 특별한 변수 표기 없이 바로 함수 이름 앞에 d를 붙임으로써 전도함수를 표현한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 합성함수

# %% [markdown]
# ## [합성함수란?](https://j1w2k3.tistory.com/495)
# - $f: X -> Y$
# - $g: Y -> Z$
#
# $f(x)$와 $g(y)$의 함수가 있다면, 합성함수는 $g(f(x))$로 표현할 수 있다.
# - $g \circ f: X -> Z$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## [합성함수 미분](https://j1w2k3.tistory.com/1100)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # [딥러닝에서 '기울기(Gradient)'란?](https://airsbigdata.tistory.com/191)

# %% [markdown]
# - 기계학습(또는 딥러닝)에서 모든 변수를 미분하여 벡터로 정리한 것을 기울기(Gradient)라고한다.
# - 이는 기계학습에서 손실 함수(loss function, 예측값과 실제값과 차이 정도로 이해하자)를 경사하강법(gradient descent)을 통해 최솟값을 갖는 지점을 찾는다.
# - 여기서 경사하강법(gradient descent)은 기울기를 이용해서 함수의 최솟값이 어디에 있는지 찾는다.
#
# 기울기를 통해서 손실함수의 최소값이 그쪽에 있는지 보는 것이며 최소한의 방향을 나타낸다. (기울기가 0이라고 반드시 그 지점이 최솟값이라고 할 수 없지만 말이다.)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - W0와 W1을 찾기 위해서 W0와 W1의 초기값을 설정을 한뒤에 반복 연산(예: for loop, while loop)을 돌린다.
# - 새로운 W를 위해 현재 위치 W에서 Learning rate(알파)와 기울기를 뺀다.
# - 'Gradient의 알파만큼 반대로 움직여라'는 것이며, 이를 경사하강법(Gradient Descent)이라고하 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Gradient Vector(기울기 백터)
# - https://www.youtube.com/watch?v=he__Xh4XGsA

# %% [markdown]
# ## 경사하강법 참고 문서들
# - https://www.youtube.com/watch?v=ENnLNkBghhE
# - https://www.youtube.com/watch?v=Ei_md7n40mA
# - https://www.youtube.com/watch?v=bUNqn1G1O7E&list=PL5yujGYFVt0DWBR51ChHdyZAFQ-kYQNgj
