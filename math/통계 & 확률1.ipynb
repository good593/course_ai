# %% [markdown]
# # 통계란?
# 통계는 데이터의 수집, 분석, 추론, 요약 등의 방법론을 다룬다.

# %% [markdown]
# - Design(설계/계획)
# - Description(요약)
# 데이터를 요약 표현하기 위한 시각적(Graphical), 수치적(numerical) 방법
# - Inference(추론)
# 표본에 기반한 모집단에 대한 추론/예측

# %% [markdown]
# # [모집단/모수/표본/통계량](https://www.youtube.com/watch?v=XP4cMk1iMUs)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 모집단(Poplulation)
# 통계학에서 관심/조사의 대상이 되는 개체의 전체 집합

# %% [markdown]
# ## 모수(Parameter)
# 모집단에 대한 수치적 요약
# - 고등학생의 1일 평균 온라인게임 플레이 시간
# - 강아지보다 고양이를 좋아하는 성인의 비율

# %% [markdown]
# ## 표본(Sample)
# 모집단을 적절히 대표하는 모집단의 일부

# %% [markdown]
# ## 통계량(Statistic)
# 표본에 대한 수치적 요약
# - 고등학생 1000명의 1일 평균 온라인게임 플레이 시간
# - 강아지보다 고양이를 좋아하는 성인의 비율(1000명)
#
# Sample statistic(표본 통계량)을 통해서 Population parameter(모집단 모수)를 예측하고 이해하는 과정이 통계의 목적이라고 생각하면 된다.

# %% [markdown]
# # [자료의 종류](https://lucete1504.tistory.com/12)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 범주형 자료
# 속성의 범주화, 상대적 서열도 표현
# - 명복형 자료: 단순히 속성을 분류하기 위함(혈액형)
# - 순서형 자료: 상대적인 크기 비교(만족도, 최종학력, 학점)

# %% [markdown]
# ## 양적 자료
# 자료자체가 숫자로 표현됨
# - 이산형 자료: 셀 수 있음 (빈도수, 불량품의 수)
# - 연속형 자료: 셀 수 없음 (길이, 시간)

# %% [markdown]
# # 통계량

# %% [markdown]
# ## 중심: 데이터의 중심

# %% [markdown]
# ### 최빈값(mode)
# - 발생빈도가 가장 높은 값
# - 극단값에 영향을 받지 않음
# - 주로 범주형 자료에 대한 대표값
# - 2개 이상 존재 가능

# %% [markdown]
# ### 중앙값(median)
# - 크기 순으로 정렬된 자료에서 가운데에 위치하는 값
# - 관측값 변화에 민감하지 않음
# - 극단값에 영향을 받지 않음

# %% [markdown]
# ### 산술평균(Arithmetic Mean)
# - 모든 자료의 값을 더하여 자료의 수로 나누어 준 값
# - 모든 값을 반영하므로 극단값에 영향을 받음
# $$
# \bar{x} = { \sum{x_i} \over n } = { x_1 + x_2 + ... + x_n \over n }
# $$

# %% [markdown]
# ### 가중평균(Weighted Mean)
# - 자료의 중요성이 각기 다를 경우
# - 중요도에 따라 가중치를 부여한 평균
# $$
# \bar{X} = { \sum{w_i\bar{X_i}} \over \sum{w_i} } = { w_1\bar{X_1} + w_2\bar{X_2} + ... + w_i\bar{X_i} \over w_1 + w_2 + ... + w_i}
# $$

# %% [markdown]
# ### [기하평균(Geometric Mean)](https://www.oppadu.com/%EC%97%91%EC%85%80-%EA%B8%B0%ED%95%98%ED%8F%89%EA%B7%A0/)
# - 자료가 성장률, 증가율 등 앞 시점에 대한 비율로 나타난 경우 유용한 통계량
# - 음수가 아닌 자료값 only
# - 연간 물가 상승률
# Ex) 일일 주가 상승률: 1% 3% 5% 10% : 1.0374....
#
# $$
# 기하평균(G) = \sqrt[n]{ \prod^n x_i }
# $$
# $$
# (x_i = 상승률)
# $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 산포: 데이터의 퍼진 정도

# %% [markdown]
# ### 분산(Variance)
# - 편차 제곱의 합을 자료의 수로 나눈 값
# - $\bar{x}$: 산술평균
# - $(x_i - \bar{x})^2$: 편차 제곱
# $$
# s^2 = \sum^n{(x_i-\bar{x})^2 \over (n -1)}
# $$

# %% [markdown]
# ### 표준편차(Standard Deviation)
# - 분산을 제곱근한 값
# $$
# s = \sqrt{ s^2 } = \sqrt{ \sum^n{ (x_i - \bar{x})^2 \over (n-1) } }
# $$

# %% [markdown]
# ## 형태: 데이터의 형태

# %% [markdown]
# ### 왜도(Skewness)
# - 분포의 비대칭도
# - Mode(최빈값), Median(중앙값), Mean(산술평균)
#
# <Positive Skew인 경우>
# - Mean > Median > Mode
#
# <Symmetrical Distribution인 경우>
# - Mean = Median = Mode
#
# <Negative Skew인 경우>
# - Mode > Median > Mean

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 첨도(Kurtosis)
# - 뽀족한 정도
# - 표준정규분포의 첨도는 3이 된다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 상관: 데이터간의 상관관계 표현
# - 상관(Correlation)이란?
#   - 확률변수 X,Y의 변화가 서로 관계가 일을 때 상관관계가 있다고 함
#   - 선형적 관련성을 파악함

# %% [markdown]
# ### [공분산(Covariance)](https://supermemi.tistory.com/entry/%ED%99%95%EB%A5%A0%EA%B3%BC-%ED%86%B5%EA%B3%84-%EB%B6%84%EC%82%B0variance-Var%EA%B3%BC-%EA%B3%B5%EB%B6%84%EC%82%B0Covariance-Cor-%EC%9D%B4%EB%9E%80-2)
# - 공분산 (Covariance, Cov)는 2개의 확률변수의 상관 정도를 나타내는 값이다.
# - $(x_i - \bar{x})$: X 편차
# - $(y_i - \bar{y})$: Y 편차
#
# $$
# s_{xy} = { \sum{(x_i - \bar{x})(y_i - \bar{y})} \over n - 1 }
# $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### [피어슨 상관계수(Pearson's Correlation Coefficient)](https://nittaku.tistory.com/456)
# - 상관계수는 확률 변수의 절대적 크기에 영향을 받지 않도록 공분산을 단위화 시킨 것이다.
#
# $$
# r_{xy} = { \sum{(x_i - \bar{x})(y_i - \bar{y})} \over \sqrt{ \sum{(x_i - \bar{x})^2 \sum{(y_i - \bar{y})^2}} } } \qquad -1 <= r <= 1
# $$

# %% [markdown]
# #### 공분산의 단점
# - 공분산은 단순한 상관관계의 방향만을 알려준다.
# - 상관관계의 정도는 알 수 없다.
# (확률 변수의 단위크기가 크면 무조건 공분산의 크기가 크게 나오는 문제가 있다.)

# %% [markdown]
# #### 상관계수의 성질
# - 공분산을 두 변수의 표준편차의 곱으로 나눈 값
# - 두 양적 변수 간의 선형적 연관성의 강도 측정
# - 단위가 없음
# - 상관관계가
#   - $0 < \rho <= 1$이면 양의 상관
#   - $-1 <= \rho < 0$이면 음의 상관
#   - $\rho = 0$이면 무상관

# %% [markdown]
# # 확률

# %% [markdown]
# ## [확률 정의](https://m.blog.naver.com/mykepzzang/221855523956)

# %% [markdown]
# ### 표본공간(S)
# 랜덤한 현상의 모든 가능한 결과의 집합

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 사건(event)
# 표본공간의 부분집합

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 예제) Flipping Coin Twice
# - 표본공간(S): {HH, HT, TH, TT}
#   - H: 앞면, T: 뒷면
# - 사건(A): 동전을 두 번 던지는 시행에서 동전의 앞면이 1번만 나올 사건
# A = {HT, TH}

# %% [markdown]
# ### 확률의 고전적 정의
# 가능한 결과가 N가지이고, 각 결과가 나타날 가능성이 모두 같을 때, 사건 A에 속하는 결과가 m개라면 A의 확률
# $$
# P(A) = { m \over N }
# $$

# %% [markdown]
# ### 경험적 정의(상대도수; relative frequency)
# 무한번(매우 많이) 시도(N)를 통한 결과가 m개라면 A의 확률
# $$
# P(A) = \lim_{n \to \infty}{n \over N}
# $$

# %% [markdown]
# ### [확률의 공리적 정의](http://bigdata.dongguk.ac.kr/lectures/med_stat/_book/%ED%99%95%EB%A5%A0probability%EC%9D%B4%EB%9E%80.html)
# 표본공간 S(전체집합)에서의 임의의 사상 A(부분집합)에 대하여,
# $0 <= P(A) <= 1$이면서 `(부분집합의 확률에 대한 설명)`,
# $P(S) = 1$이면서 `(전체집합의 확률이 1임)`,
# 서로 배반인 사상들에 대하여 `(각 사건들(부분집합)간의 교집합이 없음)`
# $$
# P(A_1 \cup A_2 \cup \cdots ) = P(A_1) + P(A_2) + \cdots
# $$
# 이 때, P(A)를 사상 A의 확률이라고 함

# %% [markdown]
# ## 확률의 성질(특징)

# %% [markdown]
# - $P(A \cup B) = P(A) + P(B) - P(A \cap B)$
# - $P(A^c) = P(S) - P(A) = 1 - P(A)$
# - $A_n$이 서로 배반사상일 때,
# $P(A_1 \cup A_2 \cup \cdots \cup A_n) = P(A_1) + P(A_2) + \cdots + P(A_n)$
# - $A \subset B$이면 $P(A) <= P(B)$

# %% [markdown]
# ## [조건부 확률(conditional probability)](https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=mykepzzang&logNo=220834864348)
# 사건 A가 일어났다는 조건 하에 사건 B가 발생할 확률이며, 기호로는 아래와 같다.
# $$
# P(B|A) = { P(A \cap B) \over P(A) }
# $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 사건 A가 발생했다는 것이 전제해야 하므로 a, b 영역이 되어야 합니다. 이 a, b 영역 중에서 사건 B가 발생한 것이기 때문에 b 영역이 조건부 확률 집합입니다.

# %% [markdown]
# ## [독립과 종속](https://j1w2k3.tistory.com/773)

# %% [markdown]
# ### 독립 사건
# 한 사건의 발생이 다른 사건의 발생 확률에 영향을 주지 않음
# 사건 A와 B가 독립이면,
# - $P(A \cap B) = P(A)P(B)$
# - $P(A|B) = P(A)$
# - $P(B|A) = P(B)$

# %% [markdown]
# ### 종속 사건
# 한 사건의 발생이 다른 사건의 발생 확률에 영향을 줌
# - $P(A \cap B) = P(A|B)P(B) = P(B|A)P(A)$

# %% [markdown]
# ## [베이즈 정리](https://angeloyeo.github.io/2020/01/09/Bayes_rule.html)

# %% [markdown]
# ### 베이즈 정리의 공식
# - 아래 공식을 보면 총 네 개의 확률값이 적혀져 있으며, 생김새도 거의 비슷비슷해 그냥 보기에는 의미를 파악하기가 어렵다.
# - 네 개의 확률 값 중 $P(H)$와 $P(H|E)$는 각각 사전 확률, 사후 확률이라고 부른다.
#
# $$
# P(H|E) = { P(H \cap E) \over P(E) } = { P(E|H)P(H) \over P(E) }
# $$
#
# `베이즈 정리는 근본적으로 사전확률 P(H)과 사후확률 P(H|E) 사이의 관계를 나타내는 정리이다.`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - H: 원인
# - E: 관측값(결과)
# - P(H)는 원인의 가능성(`사전 확률; prior`)
# - P(E|H)는 원인 H의 결과로서 E가 관측될 확률(`가능도; Likelihood`)
# - P(H|E)는 E가 관측된 후에 원인 H의 가능성(`사후 확률; posterior`)
#
# 따라서 P(H)는 어떤 사건이 발생했다는 주장에 관한 신뢰도, P(H|E)는 새로운 정보를 받은 후 갱신된 신뢰도를 의미한다.

# %% [markdown]
# ### 베이즈 정리의 의미
# - 베이즈 정리는 새로운 정보를 토대로 어떤 사건이 발생했다는 주장에 대한 신뢰도를 갱신해 나가는 방법(a method to update belief on the basis of new information)이다.
# - 가령 동전의 앞면이 나올 확률이 50%라고 하면, 빈도주의자들은 100번 동전을 던졌을 때 50번은 앞면이 나온다고 해석하고, 베이지안 주의자들은 동전의 앞면이 나왔다는 주장의 신뢰도가 50%라고 보는 것.

# %% [markdown]
# ### 베이즈 정리 예제

# %% [markdown]
# 질병 A의 발병률은 0.1%로 알려져있다. 이 질병이 실제로 있을 때 질병이 있다고 검진할 확률(민감도)은 99%, 질병이 없을 때 실제로 질병이 없다고 검진할 확률(특이도)는 98%라고 하자.
#
# 만약 어떤 사람이 질병에 걸렸다고 검진받았을 때, 이 사람이 정말로 질병에 걸렸을 확률은?

# %% [markdown]
# `Solution`
# 이런 종류의 베이즈 정리를 이용한 문제를 잘 해결하기 위해서는 앞서 언급했던 Hypothesis와 Evidence를 잘 정의할 수 있어야 한다.
#
# 이 문제에서 Hypothesis와 Evidence는 다음과 같이 정의할 수 있다.
# - Hypothesis: True이다. 즉 실제로 병이 있다.
# - Evidence: Positive로 출력되었다. 즉, 병이 있다고 진단 받았다.
#
# 따라서 기본적으로 질병 A의 발병률은 0.1%이므로 임의의 사람이 이 질병에 걸렸을 확률은 P(H)로 쓸 수 있으며, P(H) = 0.001이다.
# 또한 문제에서 주어진 민감도와 특이도는 각각 True Positive와 True Negative에 해당되는 것이고 각각 $P(E|H) = 0.99$, $P(E^c|H^c) = 0.98$이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # [확률 변수와 확률 분포](https://drhongdatanote.tistory.com/49)

# %% [markdown]
# ## 확률 변수(Random Variable)

# %% [markdown]
# - 변수(Variable)이란 특정 조건에 따라 변하는 값을 의미합니다.
# - 확률 변수(Random Variable)는 확률에 따라 변하는 값을 의미합니다.
# > 확률 변수는 임의(Random)로 진행되는 실험(예: 동전을 무작위로 두번 던져서 그림 또는 숫자가 나오는 실험)에서 일정한 확률(예: 그림이 나올 확률 1/2, 숫자가 나올 확률 1/2)을 가지고 발생하는 결과에 실수 값(예: 그림=1, 숫자=0)을 부여하는 변수(Variable)를 말합니다.
#
# 대표적인 확률 변수의 종류에는 `이산확률 변수(Discrete random variable)`와 `연속확률 변수(Continuous random variable)`가 있습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 확률 분포(Probability distribution)
# 확률 분포란 확률변수의 모든 값과 그에 대응하는 확률들이 어떻게 분포하고 있는지를 말합니다.
#
# - 확률 함수(Probability Function):
# 확률 함수 P(X)는 확률변수 X에 의해 정의된 실수를 확률(0~1)에 대응시키는 함수를 말합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 확률변수와 확률분포 관계

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 왜 확률변수와 확률함수를 알아야 할까?
# 확률 함수는 확률 변수가 일어날 확률을 나타내는 함수임으로, 우리가 특정 확률 변수의 확률 함수를 알고 있다면, 특정 사건이 일어날 확률을 계산(예측)할 수 있기 때문입니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 통계 - 참고 문서들
# [의학 통계]
# - http://bigdata.dongguk.ac.kr/lectures/med_stat/_book/%ED%99%95%EB%A5%A0probability%EC%9D%B4%EB%9E%80.html
#
# [Khan Academy] 확률과 통계
# - https://ko.khanacademy.org/math/statistics-probability
#
# [고려대 통계학과] 통계 기초 개념과 공식
# - https://youtube.com/watch?v=YaCQrJCgbqg&feature=share
# - https://www.youtube.com/watch?v=JgqZNWKKr98
#
# [classlive] 통계 공식과 개념들
# - https://www.youtube.com/watch?v=CQA7cdxozHY
