# %% [markdown]
# # microsoft
# - https://github.com/microsoft/ML-For-Beginners/tree/main/7-TimeSeries
# - https://github.com/microsoft/forecasting/tree/master/examples/grocery_sales/python
# - https://github.com/microsoft/StemGNN

# %% [markdown]
# - [시계열 분석 기반 파이썬 실습 1시간 완성 강의](https://www.youtube.com/watch?v=A72K6699kho)

# %% [markdown]
# - [물가를 예측하는 인공지능](https://www.youtube.com/watch?v=C_MOtffSues)
# - [페이스북 Prophet으로 주식 예측](https://www.youtube.com/watch?v=Sm-YBPUe3qU)
# - [파이썬으로 주식 시계열 분석](https://www.youtube.com/watch?v=RsC5NnqDFxg)
# - [주식투자 시스템 트레이딩](https://www.youtube.com/watch?v=ED04jGkp4Sg)
# - [금용과 딥러닝](https://www.youtube.com/watch?v=dB8cpsnZ5FA)
# - [인공지능으로 예측](https://www.youtube.com/watch?v=sG_WeGbZ9A4)
