# %% [markdown]
# # [Visual Embedding](https://wikidocs.net/144583)

# %% [markdown]
# # [Visual Recommendation System](https://wikidocs.net/150826)

# %% [markdown]
# # [Vision Transformer](https://www.thedatahunt.com/trend-insight/vision-transformer)

# %% [markdown]
# - https://hongl.tistory.com/232
#   - https://hongl.tistory.com/233
#   - https://hongl.tistory.com/234
#   - https://hongl.tistory.com/235
#
# - https://haystar.tistory.com/95
# - https://kimbg.tistory.com/31#google_vignette
# - https://huggingface.co/docs/transformers/model_doc/visual_bert
