# %% [markdown]
# - ChatGPT
#   - https://wikidocs.net/231364
#
# - LLama
#   - https://colab.research.google.com/github/pinecone-io/examples/blob/master/learn/generation/llm-field-guide/llama-2/llama-2-13b-retrievalqa.ipynb#scrollTo=hVu2KHaMLM2M
