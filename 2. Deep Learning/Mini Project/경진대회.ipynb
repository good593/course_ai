# %% [markdown]
# # 캐글 학습용 경진대회들
# - https://kaggle-kr.tistory.com/32

# %% [markdown]
# # 비전 경진대회
# - https://www.kaggle.com/c/statoil-iceberg-classifier-challenge
# - https://dacon.io/competitions/official/236082/overview/description
# - https://www.kaggle.com/datasets/muratkokludataset/rice-image-dataset?datasetId=2049052&sortBy=voteCount&searchQuery=torch+

# %% [markdown]
# ## NLP 경진대회
# - https://www.kaggle.com/datasets/clmentbisaillon/fake-and-real-news-dataset/code?datasetId=572515&sortBy=voteCount&searchQuery=torch
# - https://www.kaggle.com/datasets/nicapotato/womens-ecommerce-clothing-reviews/code?datasetId=11827&searchQuery=torch
# - https://www.kaggle.com/datasets/bittlingmayer/amazonreviews/code?datasetId=1305&sortBy=voteCount&searchQuery=torch
# - https://www.kaggle.com/datasets/rmisra/news-headlines-dataset-for-sarcasm-detection/code?datasetId=30764&sortBy=voteCount&searchQuery=torch
# - https://www.kaggle.com/competitions/spooky-author-identification/overview
# - https://www.kaggle.com/competitions/jigsaw-toxic-comment-classification-challenge/code?competitionId=8076&sortBy=voteCount&searchQuery=torch
